# %% [markdown]
# # Voice Pitch Tracker

# %% [markdown]
# # Imports

# %% [markdown]
# Importing the needed libraries for the entire project

# %%
% load_ext autoreload
% autoreload 2
#https://github.com/ina-foss/inaSpeechSegmenter
# !pip install inaSpeechSegmenter
# !pip install praat-parselmouth
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as scsig
from scipy.signal import detrend
from scipy.signal import find_peaks
import pandas as pd
from getpass import getpass
import urllib
import pickle
import collections
from scipy.io import wavfile as wav
from scipy.signal import fftconvolve, find_peaks, decimate, correlate, resample_poly
import pandas as pd
import parselmouth
from inaSpeechSegmenter import Segmenter, seg2csv
# Out:
# Collecting inaSpeechSegmenter
#   Downloading https://files.pythonhosted.org/packages/2e/91/ca24eedb7f7fed5849e31180f69394545531b9151b9b8a0a90196966454c/inaSpeechSegmenter-0.6.2-py3-none-any.whl (13.8MB)
#      |████████████████████████████████| 13.9MB 305kB/s
# Collecting sidekit
#   Downloading https://files.pythonhosted.org/packages/6b/ef/4a1c4bef022b5d467d970a33a4e8cb0140b1eb0f15a1c013f01dac46859d/SIDEKIT-1.3.6.6.tar.gz (151kB)
#      |████████████████████████████████| 153kB 49.8MB/s
# Collecting pyannote.parser
#   Downloading https://files.pythonhosted.org/packages/5f/24/90cf78a16c74c247afb2ddd9dfc04a051e5159440f197439bc5cbf53ca78/pyannote.parser-0.8-py3-none-any.whl
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from inaSpeechSegmenter) (2.3.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from inaSpeechSegmenter) (3.2.1)
# Collecting Pyro4
#   Downloading https://files.pythonhosted.org/packages/c3/3c/422f6f761076c5679215178a00eca9a68aacfbbc88152c85b15928b60e25/Pyro4-4.80-py2.py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 10.1MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from inaSpeechSegmenter) (1.0.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.6/dist-packages (from inaSpeechSegmenter) (0.16.2)
# Collecting pyannote.algorithms
#   Downloading https://files.pythonhosted.org/packages/79/ad/b06f0d85b71f89ef1e4d9f1b941a41c10b230a63cd9ea23d85b3694eefe0/pyannote.algorithms-0.8-py3-none-any.whl (78kB)
#      |████████████████████████████████| 81kB 9.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from inaSpeechSegmenter) (1.18.4)
# Collecting pyannote.core
#   Downloading https://files.pythonhosted.org/packages/05/f0/d5719d6316975d55035f22b303dd7cbede06de29879b790a40dd947ac662/pyannote.core-4.0-py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 8.7MB/s
# Collecting mock>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/cd/74/d72daf8dff5b6566db857cfd088907bb0355f5dd2914c4b3ef065c790735/mock-4.0.2-py3-none-any.whl
# Collecting nose>=1.3.4
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 52.5MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (2.8.1)
# Requirement already satisfied: scipy>=0.12.1 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (1.4.1)
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (1.12.0)
# Requirement already satisfied: torch>=1.0 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (1.5.0+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (0.6.0+cu101)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (3.13)
# Requirement already satisfied: h5py>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from sidekit->inaSpeechSegmenter) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->inaSpeechSegmenter) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->inaSpeechSegmenter) (1.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->inaSpeechSegmenter) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->inaSpeechSegmenter) (1.2.0)
# Collecting serpent>=1.27; python_version >= "3.2"
#   Downloading https://files.pythonhosted.org/packages/b4/a1/24871492bfc34ea18aee3bf38e0cee22d8c11d8d5e765ccc921103140747/serpent-1.30.2-py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->inaSpeechSegmenter) (2018.9)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->inaSpeechSegmenter) (2.4)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->inaSpeechSegmenter) (2.4.1)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->inaSpeechSegmenter) (1.1.1)
# Requirement already satisfied: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->inaSpeechSegmenter) (7.0.0)
# Requirement already satisfied: xarray>=0.8.2 in /usr/local/lib/python3.6/dist-packages (from pyannote.algorithms->inaSpeechSegmenter) (0.15.1)
# Requirement already satisfied: scikit-learn>=0.17 in /usr/local/lib/python3.6/dist-packages (from pyannote.algorithms->inaSpeechSegmenter) (0.22.2.post1)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/dist-packages (from pyannote.algorithms->inaSpeechSegmenter) (0.6.2)
# Requirement already satisfied: joblib>=0.9.4 in /usr/local/lib/python3.6/dist-packages (from pyannote.algorithms->inaSpeechSegmenter) (0.15.1)
# Collecting sortedcollections>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/4a/2e/53aaa6efd7aacf5f45a1181adccd85fcd0bd97526038ee9850d67a766db1/sortedcollections-1.1.2-py2.py3-none-any.whl
# Collecting munkres>=1.0.7
#   Downloading https://files.pythonhosted.org/packages/64/97/61ddc63578870e04db6eb1d3bee58ad4e727f682068a7c7405edb8b2cdeb/munkres-1.1.2-py2.py3-none-any.whl
# Collecting typing-extensions>=3.7.4.1
#   Downloading https://files.pythonhosted.org/packages/0c/0e/3f026d0645d699e7320b59952146d56ad7c374e9cd72cd16e7c74e657a0f/typing_extensions-3.7.4.2-py3-none-any.whl
# Requirement already satisfied: dataclasses>=0.7; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from pyannote.core->inaSpeechSegmenter) (0.7)
# Collecting simplejson>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/98/87/a7b98aa9256c8843f92878966dc3d8d914c14aad97e2c5ce4798d5743e07/simplejson-3.17.0.tar.gz (83kB)
#      |████████████████████████████████| 92kB 11.3MB/s
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.6/dist-packages (from pyannote.core->inaSpeechSegmenter) (2.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0->sidekit->inaSpeechSegmenter) (0.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->inaSpeechSegmenter) (4.4.2)
# Requirement already satisfied: setuptools>=41.2 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.8.2->pyannote.algorithms->inaSpeechSegmenter) (46.3.0)
# Building wheels for collected packages: sidekit, simplejson
#   Building wheel for sidekit (setup.py) ... done
#   Created wheel for sidekit: filename=SIDEKIT-1.3.6.6-cp36-none-any.whl size=186914 sha256=4fbef3d9dce626fea827188f8d9c91189bd6bc0c0747bff3a2b513b0b40561fe
#   Stored in directory: /root/.cache/pip/wheels/85/6f/67/7606ef74d759900d14043cae551e34b3b0a87484ccd1a25a9f
#   Building wheel for simplejson (setup.py) ... done
#   Created wheel for simplejson: filename=simplejson-3.17.0-cp36-cp36m-linux_x86_64.whl size=114206 sha256=78bc3d437fa42015f9234905e17a3ef77a928953aa390f876883f0784f81e30c
#   Stored in directory: /root/.cache/pip/wheels/86/c0/83/dcd0339abb2640544bb8e0938aab2d069cef55e5647ce6e097
# Successfully built sidekit simplejson
# ERROR: chainer 6.5.0 has requirement typing-extensions<=3.6.6, but you'll have typing-extensions 3.7.4.2 which is incompatible.
# Installing collected packages: mock, nose, sidekit, typing-extensions, simplejson, pyannote.core, pyannote.parser, serpent, Pyro4, sortedcollections, munkres, pyannote.algorithms, inaSpeechSegmenter
#   Found existing installation: typing-extensions 3.6.6
#     Uninstalling typing-extensions-3.6.6:
#       Successfully uninstalled typing-extensions-3.6.6
# Successfully installed Pyro4-4.80 inaSpeechSegmenter-0.6.2 mock-4.0.2 munkres-1.1.2 nose-1.3.7 pyannote.algorithms-0.8 pyannote.core-4.0 pyannote.parser-0.8 serpent-1.30.2 sidekit-1.3.6.6 simplejson-3.17.0 sortedcollections-1.1.2 typing-extensions-3.7.4.2
# Collecting praat-parselmouth
#   Downloading https://files.pythonhosted.org/packages/09/7b/9fa1172a63b6277603d27bb5613559b5a8888f58e68c1698017b87b0061d/praat_parselmouth-0.3.3-cp36-cp36m-manylinux1_x86_64.whl (9.0MB)
#      |████████████████████████████████| 9.0MB 4.5MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from praat-parselmouth) (1.18.4)
# Installing collected packages: praat-parselmouth
# Successfully installed praat-parselmouth-0.3.3
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/sidekit/bosaris/detplot.py:40: MatplotlibDeprecationWarning: The 'warn' parameter of use() is deprecated since Matplotlib 3.1 and will be removed in 3.3.  If any parameter follows 'warn', they should be pass as keyword, not positionally.
#   matplotlib.use('PDF', warn=False, force=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Cloning the github repositories that contain the datasets and used packages:

# %%
# https://stackoverflow.com/a/57539179/12561086
user=input("Username: ")
user2 = 'taomasgonzalez'
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format
repo_name = 'Voice_Pitch_Tracking'
branch_name = input("Branch: ")
cmd_string = 'git clone -b {4} https://{0}:{2}@github.com/{1}/{3}.git'.format(user,user2, password, repo_name,branch_name)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable

# https://stackoverflow.com/a/4383597/12561086
sys.path.insert(1, '/content/Voice_Pitch_Tracking/Code/')
import segmentAlgorithms as SDA
import PDA as PDA
#from midiBuilder import MidiBuilder
# Out:
# Username: taomasgonzalez
# Password: ··········
# Branch: master

# %% [markdown]
# #Function Definitions

# %% [markdown]
# ##Pitch and Audio Plotter
# Functions that plot current audio, annotated Pitch during voice and estimated pitch are made:

# %%
#
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

#
def plotter(Voice, Pitch_Annot,Pitch_Meas, Meas_Ov, Meas_Win,fs): 
  t=np.arange(0.,len(Voice)/fs,1/fs)
  t_p_An=[0]*len(Pitch_Annot)
  t_p_An[0]=0.032/2
  t_p_An[1:]=[ (2*i+1)/2*0.032-0.022*(i-1) for i in range(1,len(Pitch_Annot))]
  
  t_p_Mes=[0]*len(Pitch_Meas)
  t_p_Mes[0]=Meas_Win/2
  t_p_Mes[1:] = [(2*i+1)/2*Meas_Win-Meas_Ov*(i-1) for i in range(1,len(Pitch_Meas))]

  fig, host = plt.subplots(figsize=(20,20))
  fig.subplots_adjust(right=0.75)
  
  par1 = host.twinx()

  p1, = host.plot(t, Voice, "b-", label="Voice")
  p2, = par1.plot(t_p_An, Pitch_Annot, "r-", label="Pitch_Annotation")
  p3, = host.plot(t, Voice, "c-", label="Voice1")
  p4, = par1.plot(t_p_Mes,Pitch_Meas,"g-",label="Pitch_Meas")

  #Fijo limites en X
  host.set_xlim(0, len(t)/fs)
  #Fijo limites en Y para el primer eje
  host.set_ylim(np.amin(Voice), np.amax(Voice))
  #Fijo limites en Y para el segundo eje
  par1.set_ylim(-2, 500)

  host.set_xlabel("Tiempo [s]")
  host.set_ylabel("Amplitud de Voz")
  par1.set_ylabel("Pitch [Hz]")

  host.yaxis.label.set_color(p1.get_color())
  par1.yaxis.label.set_color(p2.get_color())
  tkw = dict(size=4, width=1.5)
  host.tick_params(axis='y', colors=p1.get_color(), **tkw)
  par1.tick_params(axis='y', colors=p2.get_color(), **tkw)

  host.tick_params(axis='x', **tkw)

  lines = [p1,p3,p2,p4]

  host.legend(lines, [l.get_label() for l in lines])
  plt.grid(True)
  plt.show()


#
def draw_spectrogram(spectrogram, dynamic_range=70):
    X, Y = spectrogram.x_grid(), spectrogram.y_grid()
    sg_db = 10 * np.log10(spectrogram.values)
    plt.pcolormesh(X, Y, sg_db, vmin=sg_db.max() - dynamic_range, cmap='afmhot')
    plt.ylim([spectrogram.ymin, spectrogram.ymax])
    plt.xlabel("time [s]")
    plt.ylabel("frequency [Hz]")

#
def draw_pitch(pitch):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']
    pitch_values[pitch_values==0] = np.nan
    plt.plot(pitch.xs(), pitch_values, 'o', markersize=5, color='w')
    plt.plot(pitch.xs(), pitch_values, 'o', markersize=2,label="Praat")
    plt.grid(False)
    plt.ylim(0, pitch.ceiling)
    plt.ylabel("fundamental frequency [Hz]")

#
def draw_pitch2(Pitch_Annot, Pitch_Meas, Meas_Ov, Meas_Win,fs):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    t_p_An=[0]*len(Pitch_Annot)
    t_p_An[0]=0.032/2
    t_p_An[1:]=[ (2*i+1)/2*0.032-0.022*(i-1) for i in range(1,len(Pitch_Annot))]
  

    
    plt.plot(t_p_An, Pitch_Annot, 'o', markersize=5, color='w')
    plt.plot(t_p_An, Pitch_Annot, 'o', markersize=2,color="g",label="RAPT")

    t_p_Mes=[0]*len(Pitch_Meas)
    t_p_Mes[0]=Meas_Win/2
    t_p_Mes[1:] = [(2*i+1)/2*Meas_Win-Meas_Ov*(i-1) for i in range(1,len(Pitch_Meas))]

    plt.plot(t_p_Mes, Pitch_Meas, 'o', markersize=5, color='w')
    plt.plot(t_p_Mes, Pitch_Meas, 'o', markersize=2,color="r",label="Meas")

    plt.grid(False)
    plt.legend()
    plt.ylim(0, np.amax(Pitch_Annot))
    plt.ylabel("fundamental frequency [Hz]")

#
def spectrogram_plotter(parcelmouth_snd,Pitch_Annot,Pitch_Meas, Meas_Ov, Meas_Win,fs):

  pitch = parcelmouth_snd.to_pitch()
  # If desired, pre-emphasize the sound fragment before calculating the spectrogram
  pre_emphasized_snd = parcelmouth_snd.copy()
  pre_emphasized_snd.pre_emphasize()
  spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
  plt.figure(figsize=(20,20))
  draw_spectrogram(spectrogram)
  plt.twinx()
  #draw_pitch(pitch)
  draw_pitch2(Pitch_Annot,Pitch_Meas, Meas_Ov, Meas_Win,fs)
  plt.xlim([parcelmouth_snd.xmin, parcelmouth_snd.xmax])
  plt.show() # or plt.savefig("spectrogram_0.03.pdf")

def plot_error(Pitch_Annot, Pitch_Meas, Meas_Ov, Meas_Win, fs):
  
  t_p_An=[0]*len(Pitch_Annot)
  t_p_An[0]=0.032/2
  t_p_An[1:]=[ (2*i+1)/2*0.032-0.022*(i-1) for i in range(1,len(Pitch_Annot))]
  
  t_p_Mes=[0]*len(Pitch_Meas)
  t_p_Mes[0]=Meas_Win/2
  t_p_Mes[1:] = [(2*i+1)/2*Meas_Win-Meas_Ov*(i-1) for i in range(1,len(Pitch_Meas))]

  if len(Pitch_Meas) < len(Pitch_Annot):
    t = t_p_Mes
    Pitch_Annot = Pitch_Annot[0:len(Pitch_Meas)]
  else:
    t = t_p_An
    Pitch_Meas = Pitch_Meas[0:len(Pitch_Annot)]

  plt.plot(t, abs(Pitch_Annot- Pitch_Meas))
  plt.xlabel('Tiempo [s]')
  plt.ylabel('Error absoluto [Hz]')

# %% [markdown]
# ##Evaluate Algorithm Performance
#
# Functions that evaluate the performance of the algorithm compared to the dataset.
#
# To validate our algorithms, we measure the gross error rate produced by our algorithm.
#
# We define the gross error rate as the ratio $\frac{G_e}{T}$.
#
# Where $G_e$ is the amount of time frames for which our algorithm gave out a frequency that deviated more than 20% from the reference values provided by the dataset. $T$ is the total amount of time frames of the speech signal.
#
# This criteria was based on the evaluation of the performance of the YIN algorithm. See https://www.researchgate.net/publication/11367890_YIN_A_fundamental_frequency_estimator_for_speech_and_music for more detail.

# %%
# check performance returns the relative error of the pitches returned by any 
# pitch tracking algorithm (given by Pitch_Meas) in comparison with the pitches 
# obtained from the dataset for that speech signal (given by Pitch_Annot)
# Meas_Ov : Overlap for the pitch tracking algorithm.
# Meas_Win : Len of the window used for the pitch tracking algorithm.
def check_performance(Pitch_Annot, Pitch_Meas, Meas_Ov, Meas_Win, fs):

  t_p_An=[0]*len(Pitch_Annot)
  t_p_An[0]=0.032/2
  t_p_An[1:]=[ (2*i+1)/2*0.032-0.022*(i-1) for i in range(1,len(Pitch_Annot))]
  
  t_p_Mes=[0]*len(Pitch_Meas)
  t_p_Mes[0]=Meas_Win/2
  t_p_Mes[1:] = [(2*i+1)/2*Meas_Win-Meas_Ov*(i-1) for i in range(1,len(Pitch_Meas))]
  
  if len(Pitch_Meas) < len(Pitch_Annot):
    t = t_p_Mes
    Pitch_Annot = Pitch_Annot[0:len(Pitch_Meas)]
  else:
    t = t_p_An
    Pitch_Meas = Pitch_Meas[0:len(Pitch_Annot)]
  
  absolute_error = abs(Pitch_Annot - Pitch_Meas)
  relative_error = absolute_error / abs(Pitch_Annot)

  return len(relative_error[relative_error > 0.2]) / len(t) * 100

# %% [markdown]
# # Applying the algorithm

# %%
def create_midi(voice_path, annot_path,gender, algorithm='YIN', plot=False):

    algos = {'ACF': PDA.autocorrelationAlgorithm,'YIN': YIN, 'HPS':harmonicProductSpectrum} 
    curr_algo = algos[algorithm]
    
    seg = Segmenter()
    vda_segmentation = seg(voice_path)
    #print(vda_segmentation)

    fs, audio = wav.read(voice_path)
    audio_mono = audio
    audio_mono =audio_mono/ np.max(np.abs(audio_mono))
    audio_mono = audio_mono-np.mean(audio_mono)

    data = pd.read_table(annot_path, delim_whitespace=True, names=('Pitch', 'P_Voice', 'RMSE','P_NCCS'))
    Pitch_Annot = data["Pitch"]

    wind_sec=0.032
    hop_sec=0.01

    note_segments = SDA.notes_segmentation(len(audio_mono),vda_segmentation, fs, window_seconds=wind_sec, overlap_seconds=hop_sec)

    # find the pitch of each segment. notes_fo[i] will be -1 if the segment is unvoiced
    freqs_fo, pitches_fo = assign_pitch(audio_mono, fs, note_segments,gender, curr_algo)

    if plot:

      snd = parselmouth.Sound(voice_path)
      
      plotter(audio_mono, Pitch_Annot,freqs_fo, wind_sec-hop_sec, wind_sec,fs)

      spectrogram_plotter(snd,Pitch_Annot,freqs_fo, wind_sec-hop_sec, wind_sec,fs)

      plot_error(Pitch_Annot, freqs_fo, wind_sec-hop_sec, wind_sec, fs)

      plt.figure(figsize=(20,20))
      plt.plot(freqs_fo)

    return check_performance(Pitch_Annot, freqs_fo, wind_sec-hop_sec, wind_sec, fs)

# %% [markdown]
# We apply the algorithm for only one file

# %%
def assign_pitch(data_in, fs, segments, gender, algorithm ):
    n_windows = len(segments[:])
    notes_fo = np.zeros(n_windows, dtype=int)
    freqs_fo = np.zeros(n_windows, dtype=int)

    for i in range(0, n_windows):
        # print("De ",segments[i][1]/fs,"sec a ", segments[i][2]/fs," sec")
        if segments[i][0] == 1:
            f = algorithm(data_in[segments[i][1]:segments[i][2]], fs, gender)
            freqs_fo[i] = f
            notes_fo[i] = freqToPitch(freqs_fo[i])
        else:
            notes_fo[i] = 0

    return freqs_fo, notes_fo

from scipy.fftpack import rfft, irfft, ifftshift
from scipy.fft import dct

def harmonicProductSpectrum(noteData, fs,gender, form="dct", hNro=3):
    fo = 0
    # aplico ventana
    window = np.hanning(len(noteData))
    noteData = np.multiply(window, noteData)
    # fft de los datos
    if form=="fft":
      fftData =rfft(noteData)
    elif form=="dct":
      fftData = dct(noteData)
    fftData = abs(fftData[:])
    k = np.arange(len(noteData))
    T = (2 * len(noteData)) / fs
    fftF = k / T
    fftArray = []
    fftArray.append(fftData)
    # downsample for un factor de 2 a hNro
    for i in range(2, hNro + 1):
        auxfft = decimate(fftData, i)
        auxfft = abs(auxfft[:])
        # relleno con ceros para que coincidan en tamaño
        cant = len(fftData) - len(auxfft)
        zeros = np.zeros(cant)
        auxfft = np.concatenate((auxfft, zeros))
        fftArray.append(auxfft)
    # multiplico todas las fft de fftArray
    hpsArray = []
    for i in range(0, len(fftData)):
        auxElement = 1
        for j in range(0, hNro):
            auxElement = auxElement * fftArray[j][i]
        hpsArray.append(auxElement)
    # elimino picos antes de los 20Hz
    index = 0
    while fftF[index] < 20:
        index = index + 1
    for i in range(0, index):
        hpsArray[i] = 0
    # busco frecuencia del maximo de la nueva funcion
    max_hps = np.argmax(hpsArray)
    fo = fftF[max_hps]
    peaks, _  = find_peaks(hpsArray, height=hpsArray[max_hps]*0.65)
    sec_peak= 0
    for k in range(len(peaks)):
      if peaks[k] < max_hps*0.9 and peaks[k] > max_hps*0.4:
        sec_peak=peaks[k]
        ratio = np.array(hpsArray)[sec_peak]/np.array(hpsArray)[max_hps]
        #print(ratio)
        if ratio< 0.95 and ratio > 0.63:
            fo =fftF[sec_peak]
        break

    """plt.plot(hpsArray[0:50])
    if len(peaks) > 0:
        print(peaks)
        plt.plot(peaks, np.array(hpsArray)[peaks], "x")
    plt.show()
    plt.plot()"""

    if gender == "MALE" and (fo > 220 or fo<30):
      fo = 0
    if gender== "FEMALE" and (fo > 315 or fo < 130):
      fo = 0
    return fo

def YIN(data, fs, gender,  tauMax=1 / 40, form='cumsum', th=0.6):
    if gender == 'MALE':
      th = 1
      cross_th = 25
    else:
      th = 0.3
      cross_th = 40
    # let s call len(data) = w
    # we will start by calculating DF = sum(j = 1, w, (x(j) - x(j+tau))^2)
    # DF = sum(j=1, w, x(j) ^ 2) -2 * sum(j=1, w, x(j)*x(j+tau)) + sum(j=1, w, x(j+tau) ^ 2)
    # calculate power and z(tau)
    # where power = sum(j = 1, w, x^2(j))
    # and z(tau) = sum(j = 1, w, x^2(j+w))
    t = int(fs * tauMax)
    
    power = 0
    sub_powers = list()

    for i in range(1, len(data)):
        power += data[i]**2

    # z(tau) = sum(j = 1, w, x^2(j+w)) = sum(j = tau + 1, w + tau, x^2(j))
    # z(tau) = sum(j = tau + 1, w, x^2(j)) as x(w+1) = 0 and so on...
    # z(tau) = sum(j=1, w, x ^ 2(j))  - sum(j=1, tau, x ^ 2(j))
    # z(tau) = sum(j=1, w, x ^ 2(j)) - sum(j=1, tau, x ^ 2(j))
    # z(tau) = power - sum(j=1, tau, x ^ 2(j))
    # tau can take values from tau = 1 to t
    sub_powers.append(0)       # j = 0, no power just in case.
    sub_powers.append(power - data[1]**2)

    for i in range(2, t):

        if i < len(data):
            sub_powers.append(sub_powers[i-1] - data[i-1]**2)
        else:
            # may be optimized filling the rest with zeroes directly
            sub_powers.append(0)

    correl = fftconvolve(data, data[::-1], mode='full')
    correl = correl[correl.size // 2:]

    # should not add 1 as first value, as we will just be needing diff to claculate cmdf
    diff = np.array([power - 2 * correl[i] + sub_powers[i] for i in range(1, t)], dtype=np.float64)

    cmdf = list()
    cmdf.append(1)
    g_tau = 0

    for i in range(len(diff)):
        g_tau = g_tau + diff[i]
        if g_tau != 0:
            cmdf.append((i + 1) * diff[i] / g_tau)
        else:
            cmdf.append((i + 1) * diff[i] / (10 ** (-10)))

    # find fundamental frequency
    n = 0
    
    # find all peaks below th
    # peaks, _  = find_peaks(np.multiply(-1, cmdf), -th)
    cmdf = np.multiply(-1, cmdf)
    peaks, _  = find_peaks(cmdf[0:600], -th)
    
    # plt.plot(cmdf)
    # print("Amount of peaks above th: ", len(peaks))
    tot_peaks = find_peaks(cmdf, -12)[0]
    # print("Amount of peaks total: ", len(tot_peaks))
    peaks = np.array(peaks)
    peaks = peaks[peaks > 80]
    
    if len(peaks) > 0 and len(tot_peaks) < cross_th:
      # plt.plot(peaks, cmdf[peaks], "x")  
      aux_max = -1

      for p in peaks:
        if cmdf[p] > aux_max:
          aux_max = cmdf[p]
          n = p

    plt.show()
    
    if gender == "MALE" and n > 0 and n<fs/30:
        fo = fs / n
    elif gender == "FEMALE" and n > 0 and n<fs/130:
        fo = fs / n 
    else:
        fo = 0
    
    if fo>220 and gender == "MALE":
        fo = 0
    if fo>315 and gender == "FEMALE":
        fo = 0
    return fo

def freqToPitch(freq):
    pitch = 0
    if freq > 0:
        pitch = round(12 * np.log2(freq / 440) + 69)
    return pitch

# %%
error = create_midi( '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si498.wav','/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si498.f0',"FEMALE", algorithm='YIN', plot=True)
print('Gross error:', error, '%')

# error = create_midi('/content/drive/Shared drives/Pitch Tracking/MALE/MIC/M01/mic_M01_si498.wav','/content/drive/Shared drives/Pitch Tracking/MALE/REF/M01/ref_M01_si498.f0',"MALE", algorithm='YIN', plot=True)
# print('Gross error:', error, '%')

#from IPython.display import Audio
#fs, audio = wav.read('/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav')
# plt.figure(figsize=(20,20))
# plt.plot(audio[185800:192000])
#Audio(audio[184000:194000], rate=fs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# De  0.0 sec a  0.034  sec
# De  0.01 sec a  0.044  sec
# De  0.02 sec a  0.054  sec
# De  0.03 sec a  0.064  sec
# De  0.04 sec a  0.074  sec
# De  0.05 sec a  0.084  sec
# De  0.06 sec a  0.094  sec
# De  0.07 sec a  0.104  sec
# De  0.08 sec a  0.114  sec
# De  0.09 sec a  0.124  sec
# De  0.1 sec a  0.134  sec
# De  0.11 sec a  0.144  sec
# De  0.12 sec a  0.154  sec
# De  0.13 sec a  0.164  sec
# De  0.14 sec a  0.174  sec
# De  0.15 sec a  0.184  sec
# De  0.16 sec a  0.194  sec
# De  0.17 sec a  0.204  sec
# De  0.18 sec a  0.214  sec
# De  0.19 sec a  0.224  sec
# De  0.2 sec a  0.234  sec
# De  0.21 sec a  0.244  sec
# De  0.22 sec a  0.254  sec
# De  0.23 sec a  0.264  sec
# De  0.24 sec a  0.274  sec
# De  0.25 sec a  0.284  sec
# De  0.26 sec a  0.294  sec
# De  0.27 sec a  0.304  sec
# De  0.28 sec a  0.314  sec
# De  0.29 sec a  0.324  sec
# De  0.3 sec a  0.334  sec
# De  0.31 sec a  0.344  sec
# De  0.32 sec a  0.354  sec
# De  0.33 sec a  0.364  sec
# De  0.34 sec a  0.374  sec
# De  0.35 sec a  0.384  sec
# De  0.36 sec a  0.394  sec
# De  0.37 sec a  0.404  sec
# De  0.38 sec a  0.414  sec
# De  0.39 sec a  0.424  sec
# De  0.4 sec a  0.434  sec
# De  0.41 sec a  0.444  sec
# De  0.42 sec a  0.454  sec
# De  0.43 sec a  0.464  sec
# De  0.44 sec a  0.474  sec
# De  0.45 sec a  0.484  sec
# De  0.46 sec a  0.494  sec
# De  0.47 sec a  0.504  sec
# De  0.48 sec a  0.514  sec
# De  0.49 sec a  0.524  sec
# De  0.5 sec a  0.534  sec
# De  0.51 sec a  0.544  sec
# De  0.52 sec a  0.554  sec
# De  0.53 sec a  0.564  sec
# De  0.54 sec a  0.574  sec
# De  0.55 sec a  0.584  sec
# De  0.56 sec a  0.594  sec
# De  0.57 sec a  0.604  sec
# De  0.58 sec a  0.614  sec
# De  0.59 sec a  0.624  sec
# De  0.6 sec a  0.634  sec
# De  0.61 sec a  0.644  sec
# De  0.62 sec a  0.654  sec
# De  0.63 sec a  0.664  sec
# De  0.64 sec a  0.674  sec
# De  0.65 sec a  0.684  sec
# De  0.66 sec a  0.694  sec
# De  0.67 sec a  0.704  sec
# De  0.68 sec a  0.714  sec
# De  0.69 sec a  0.724  sec
# De  0.7 sec a  0.734  sec
# De  0.71 sec a  0.744  sec
# De  0.72 sec a  0.754  sec
# De  0.73 sec a  0.764  sec
# De  0.74 sec a  0.774  sec
# De  0.75 sec a  0.784  sec
# De  0.76 sec a  0.794  sec
# De  0.77 sec a  0.804  sec
# De  0.78 sec a  0.814  sec
# De  0.79 sec a  0.824  sec
# De  0.8 sec a  0.834  sec
# De  0.81 sec a  0.844  sec
# De  0.82 sec a  0.854  sec
# De  0.83 sec a  0.864  sec
# De  0.84 sec a  0.874  sec
# De  0.85 sec a  0.884  sec
# De  0.86 sec a  0.894  sec
# De  0.87 sec a  0.904  sec
# De  0.88 sec a  0.914  sec
# De  0.89 sec a  0.924  sec
# De  0.9 sec a  0.934  sec
# De  0.91 sec a  0.944  sec
# De  0.92 sec a  0.954  sec
# De  0.93 sec a  0.964  sec
# De  0.94 sec a  0.974  sec
# De  0.95 sec a  0.984  sec
# De  0.96 sec a  0.994  sec
# De  0.97 sec a  1.004  sec
# De  0.98 sec a  1.014  sec
# De  0.99 sec a  1.024  sec
# De  1.0 sec a  1.034  sec
# De  1.01 sec a  1.044  sec
# De  1.02 sec a  1.054  sec
# De  1.03 sec a  1.064  sec
# De  1.04 sec a  1.074  sec
# De  1.05 sec a  1.084  sec
# De  1.06 sec a  1.094  sec
# De  1.07 sec a  1.104  sec
# De  1.08 sec a  1.114  sec
# De  1.09 sec a  1.124  sec
# De  1.1 sec a  1.134  sec
# De  1.11 sec a  1.144  sec
# De  1.12 sec a  1.154  sec
# De  1.13 sec a  1.164  sec
# De  1.14 sec a  1.174  sec
# De  1.15 sec a  1.184  sec
# De  1.16 sec a  1.194  sec
# De  1.17 sec a  1.204  sec
# De  1.18 sec a  1.214  sec
# De  1.19 sec a  1.224  sec
# De  1.2 sec a  1.234  sec
# De  1.21 sec a  1.244  sec
# De  1.22 sec a  1.254  sec
# De  1.23 sec a  1.264  sec
# De  1.24 sec a  1.274  sec
# De  1.25 sec a  1.284  sec
# De  1.26 sec a  1.294  sec
# De  1.27 sec a  1.304  sec
# De  1.28 sec a  1.314  sec
# De  1.29 sec a  1.324  sec
# De  1.3 sec a  1.334  sec
# De  1.31 sec a  1.344  sec
# De  1.32 sec a  1.354  sec
# De  1.33 sec a  1.364  sec
# De  1.34 sec a  1.374  sec
# De  1.35 sec a  1.384  sec
# De  1.36 sec a  1.394  sec
# De  1.37 sec a  1.404  sec
# De  1.38 sec a  1.414  sec
# De  1.39 sec a  1.424  sec
# De  1.4 sec a  1.434  sec
# De  1.41 sec a  1.444  sec
# De  1.42 sec a  1.454  sec
# De  1.43 sec a  1.464  sec
# De  1.44 sec a  1.474  sec
# De  1.45 sec a  1.484  sec
# De  1.46 sec a  1.494  sec
# De  1.47 sec a  1.504  sec
# De  1.48 sec a  1.514  sec
# De  1.49 sec a  1.524  sec
# De  1.5 sec a  1.534  sec
# De  1.51 sec a  1.544  sec
# De  1.52 sec a  1.554  sec
# De  1.53 sec a  1.564  sec
# De  1.54 sec a  1.574  sec
# De  1.55 sec a  1.584  sec
# De  1.56 sec a  1.594  sec
# De  1.57 sec a  1.604  sec
# De  1.58 sec a  1.614  sec
# De  1.59 sec a  1.624  sec
# De  1.6 sec a  1.634  sec
# De  1.61 sec a  1.644  sec
# De  1.62 sec a  1.654  sec
# De  1.63 sec a  1.664  sec
# De  1.64 sec a  1.674  sec
# De  1.65 sec a  1.684  sec
# De  1.66 sec a  1.694  sec
# De  1.67 sec a  1.704  sec
# De  1.68 sec a  1.714  sec
# De  1.69 sec a  1.724  sec
# De  1.7 sec a  1.734  sec
# De  1.71 sec a  1.744  sec
# De  1.72 sec a  1.754  sec
# De  1.73 sec a  1.764  sec
# De  1.74 sec a  1.774  sec
# De  1.75 sec a  1.784  sec
# De  1.76 sec a  1.794  sec
# De  1.77 sec a  1.804  sec
# De  1.78 sec a  1.814  sec
# De  1.79 sec a  1.824  sec
# De  1.8 sec a  1.834  sec
# De  1.81 sec a  1.844  sec
# De  1.82 sec a  1.854  sec
# De  1.83 sec a  1.864  sec
# De  1.84 sec a  1.874  sec
# De  1.85 sec a  1.884  sec
# De  1.86 sec a  1.894  sec
# De  1.87 sec a  1.904  sec
# De  1.88 sec a  1.914  sec
# De  1.89 sec a  1.924  sec
# De  1.9 sec a  1.934  sec
# De  1.91 sec a  1.944  sec
# De  1.92 sec a  1.954  sec
# De  1.93 sec a  1.964  sec
# De  1.94 sec a  1.974  sec
# De  1.95 sec a  1.984  sec
# De  1.96 sec a  1.994  sec
# De  1.97 sec a  2.004  sec
# De  1.98 sec a  2.014  sec
# De  1.99 sec a  2.024  sec
# De  2.0 sec a  2.034  sec
# De  2.01 sec a  2.044  sec
# De  2.02 sec a  2.054  sec
# De  2.03 sec a  2.064  sec
# De  2.04 sec a  2.074  sec
# De  2.05 sec a  2.084  sec
# De  2.06 sec a  2.094  sec
# De  2.07 sec a  2.104  sec
# De  2.08 sec a  2.114  sec
# De  2.09 sec a  2.124  sec
# De  2.1 sec a  2.134  sec
# De  2.11 sec a  2.144  sec
# De  2.12 sec a  2.154  sec
# De  2.13 sec a  2.164  sec
# De  2.14 sec a  2.174  sec
# De  2.15 sec a  2.184  sec
# De  2.16 sec a  2.194  sec
# De  2.17 sec a  2.204  sec
# De  2.18 sec a  2.214  sec
# De  2.19 sec a  2.224  sec
# De  2.2 sec a  2.234  sec
# De  2.21 sec a  2.244  sec
# De  2.22 sec a  2.254  sec
# De  2.23 sec a  2.264  sec
# De  2.24 sec a  2.274  sec
# De  2.25 sec a  2.284  sec
# De  2.26 sec a  2.294  sec
# De  2.27 sec a  2.304  sec
# De  2.28 sec a  2.314  sec
# De  2.29 sec a  2.324  sec
# De  2.3 sec a  2.334  sec
# De  2.31 sec a  2.344  sec
# De  2.32 sec a  2.354  sec
# De  2.33 sec a  2.364  sec
# De  2.34 sec a  2.374  sec
# De  2.35 sec a  2.384  sec
# De  2.36 sec a  2.394  sec
# De  2.37 sec a  2.404  sec
# De  2.38 sec a  2.414  sec
# De  2.39 sec a  2.424  sec
# De  2.4 sec a  2.434  sec
# De  2.41 sec a  2.444  sec
# De  2.42 sec a  2.454  sec
# De  2.43 sec a  2.464  sec
# De  2.44 sec a  2.474  sec
# De  2.45 sec a  2.484  sec
# De  2.46 sec a  2.494  sec
# De  2.47 sec a  2.504  sec
# De  2.48 sec a  2.514  sec
# De  2.49 sec a  2.524  sec
# De  2.5 sec a  2.534  sec
# De  2.51 sec a  2.544  sec
# De  2.52 sec a  2.554  sec
# De  2.53 sec a  2.564  sec
# Amount of peaks total:  300
# De  2.54 sec a  2.574  sec
# Amount of peaks total:  311
# De  2.55 sec a  2.584  sec
# Amount of peaks total:  364
# De  2.56 sec a  2.594  sec
# Amount of peaks total:  260
# De  2.57 sec a  2.604  sec
# Amount of peaks total:  243
# De  2.58 sec a  2.614  sec
# Amount of peaks total:  193
# De  2.59 sec a  2.624  sec
# Amount of peaks total:  175
# De  2.6 sec a  2.634  sec
# Amount of peaks total:  170
# De  2.61 sec a  2.644  sec
# Amount of peaks total:  156
# De  2.62 sec a  2.654  sec
# Amount of peaks total:  119
# De  2.63 sec a  2.664  sec
# Amount of peaks total:  82
# De  2.64 sec a  2.674  sec
# Amount of peaks total:  81
# De  2.65 sec a  2.684  sec
# Amount of peaks total:  70
# De  2.66 sec a  2.694  sec
# Amount of peaks total:  58
# De  2.67 sec a  2.704  sec
# Amount of peaks total:  60
# De  2.68 sec a  2.714  sec
# Amount of peaks total:  55
# De  2.69 sec a  2.724  sec
# Amount of peaks total:  57
# De  2.7 sec a  2.734  sec
# Amount of peaks total:  56
# De  2.71 sec a  2.744  sec
# Amount of peaks total:  53
# De  2.72 sec a  2.754  sec
# Amount of peaks total:  54
# De  2.73 sec a  2.764  sec
# Amount of peaks total:  55
# De  2.74 sec a  2.774  sec
# Amount of peaks total:  51
# De  2.75 sec a  2.784  sec
# Amount of peaks total:  52
# De  2.76 sec a  2.794  sec
# Amount of peaks total:  52
# De  2.77 sec a  2.804  sec
# Amount of peaks total:  55
# De  2.78 sec a  2.814  sec
# Amount of peaks total:  67
# De  2.79 sec a  2.824  sec
# Amount of peaks total:  65
# De  2.8 sec a  2.834  sec
# Amount of peaks total:  57
# De  2.81 sec a  2.844  sec
# Amount of peaks total:  58
# De  2.82 sec a  2.854  sec
# Amount of peaks total:  54
# De  2.83 sec a  2.864  sec
# Amount of peaks total:  56
# De  2.84 sec a  2.874  sec
# Amount of peaks total:  56
# De  2.85 sec a  2.884  sec
# Amount of peaks total:  59
# De  2.86 sec a  2.894  sec
# Amount of peaks total:  80
# De  2.87 sec a  2.904  sec
# Amount of peaks total:  254
# De  2.88 sec a  2.914  sec
# Amount of peaks total:  256
# De  2.89 sec a  2.924  sec
# Amount of peaks total:  220
# De  2.9 sec a  2.934  sec
# Amount of peaks total:  120
# De  2.91 sec a  2.944  sec
# Amount of peaks total:  153
# De  2.92 sec a  2.954  sec
# Amount of peaks total:  174
# De  2.93 sec a  2.964  sec
# Amount of peaks total:  192
# De  2.94 sec a  2.974  sec
# Amount of peaks total:  169
# De  2.95 sec a  2.984  sec
# Amount of peaks total:  108
# De  2.96 sec a  2.994  sec
# Amount of peaks total:  118
# De  2.97 sec a  3.004  sec
# Amount of peaks total:  131
# De  2.98 sec a  3.014  sec
# Amount of peaks total:  117
# De  2.99 sec a  3.024  sec
# Amount of peaks total:  118
# De  3.0 sec a  3.034  sec
# Amount of peaks total:  116
# De  3.01 sec a  3.044  sec
# Amount of peaks total:  114
# De  3.02 sec a  3.054  sec
# Amount of peaks total:  51
# De  3.03 sec a  3.064  sec
# Amount of peaks total:  17
# De  3.04 sec a  3.074  sec
# Amount of peaks total:  11
# De  3.05 sec a  3.084  sec
# Amount of peaks total:  8
# De  3.06 sec a  3.094  sec
# Amount of peaks total:  8
# De  3.07 sec a  3.104  sec
# Amount of peaks total:  9
# De  3.08 sec a  3.114  sec
# Amount of peaks total:  30
# De  3.09 sec a  3.124  sec
# Amount of peaks total:  44
# De  3.1 sec a  3.134  sec
# Amount of peaks total:  42
# De  3.11 sec a  3.144  sec
# Amount of peaks total:  39
# De  3.12 sec a  3.154  sec
# Amount of peaks total:  42
# De  3.13 sec a  3.164  sec
# Amount of peaks total:  43
# De  3.14 sec a  3.174  sec
# Amount of peaks total:  33
# De  3.15 sec a  3.184  sec
# Amount of peaks total:  18
# De  3.16 sec a  3.194  sec
# Amount of peaks total:  13
# De  3.17 sec a  3.204  sec
# Amount of peaks total:  9
# De  3.18 sec a  3.214  sec
# Amount of peaks total:  8
# De  3.19 sec a  3.224  sec
# Amount of peaks total:  9
# De  3.2 sec a  3.234  sec
# Amount of peaks total:  9
# De  3.21 sec a  3.244  sec
# Amount of peaks total:  10
# De  3.22 sec a  3.254  sec
# Amount of peaks total:  11
# De  3.23 sec a  3.264  sec
# Amount of peaks total:  11
# De  3.24 sec a  3.274  sec
# Amount of peaks total:  11
# De  3.25 sec a  3.284  sec
# Amount of peaks total:  12
# De  3.26 sec a  3.294  sec
# Amount of peaks total:  11
# De  3.27 sec a  3.304  sec
# Amount of peaks total:  12
# De  3.28 sec a  3.314  sec
# Amount of peaks total:  14
# De  3.29 sec a  3.324  sec
# Amount of peaks total:  13
# De  3.3 sec a  3.334  sec
# Amount of peaks total:  14
# De  3.31 sec a  3.344  sec
# Amount of peaks total:  13
# De  3.32 sec a  3.354  sec
# Amount of peaks total:  13
# De  3.33 sec a  3.364  sec
# Amount of peaks total:  13
# De  3.34 sec a  3.374  sec
# Amount of peaks total:  17
# De  3.35 sec a  3.384  sec
# Amount of peaks total:  21
# De  3.36 sec a  3.394  sec
# Amount of peaks total:  12
# De  3.37 sec a  3.404  sec
# Amount of peaks total:  11
# De  3.38 sec a  3.414  sec
# Amount of peaks total:  8
# De  3.39 sec a  3.424  sec
# Amount of peaks total:  8
# De  3.4 sec a  3.434  sec
# Amount of peaks total:  17
# De  3.41 sec a  3.444  sec
# Amount of peaks total:  8
# De  3.42 sec a  3.454  sec
# Amount of peaks total:  144
# De  3.43 sec a  3.464  sec
# Amount of peaks total:  318
# De  3.44 sec a  3.474  sec
# Amount of peaks total:  298
# De  3.45 sec a  3.484  sec
# Amount of peaks total:  282
# De  3.46 sec a  3.494  sec
# Amount of peaks total:  269
# De  3.47 sec a  3.504  sec
# Amount of peaks total:  259
# De  3.48 sec a  3.514  sec
# Amount of peaks total:  249
# De  3.49 sec a  3.524  sec
# Amount of peaks total:  228
# De  3.5 sec a  3.534  sec
# Amount of peaks total:  216
# De  3.51 sec a  3.544  sec
# Amount of peaks total:  192
# De  3.52 sec a  3.554  sec
# Amount of peaks total:  102
# De  3.53 sec a  3.564  sec
# Amount of peaks total:  23
# De  3.54 sec a  3.574  sec
# Amount of peaks total:  14
# De  3.55 sec a  3.584  sec
# Amount of peaks total:  16
# De  3.56 sec a  3.594  sec
# Amount of peaks total:  14
# De  3.57 sec a  3.604  sec
# Amount of peaks total:  14
# De  3.58 sec a  3.614  sec
# Amount of peaks total:  26
# De  3.59 sec a  3.624  sec
# Amount of peaks total:  75
# De  3.6 sec a  3.634  sec
# Amount of peaks total:  90
# De  3.61 sec a  3.644  sec
# Amount of peaks total:  88
# De  3.62 sec a  3.654  sec
# Amount of peaks total:  88
# De  3.63 sec a  3.664  sec
# Amount of peaks total:  88
# De  3.64 sec a  3.674  sec
# Amount of peaks total:  85
# De  3.65 sec a  3.684  sec
# Amount of peaks total:  74
# De  3.66 sec a  3.694  sec
# Amount of peaks total:  15
# De  3.67 sec a  3.704  sec
# Amount of peaks total:  13
# De  3.68 sec a  3.714  sec
# Amount of peaks total:  12
# De  3.69 sec a  3.724  sec
# Amount of peaks total:  12
# De  3.7 sec a  3.734  sec
# Amount of peaks total:  13
# De  3.71 sec a  3.744  sec
# Amount of peaks total:  13
# De  3.72 sec a  3.754  sec
# Amount of peaks total:  12
# De  3.73 sec a  3.764  sec
# Amount of peaks total:  9
# De  3.74 sec a  3.774  sec
# Amount of peaks total:  11
# De  3.75 sec a  3.784  sec
# Amount of peaks total:  10
# De  3.76 sec a  3.794  sec
# Amount of peaks total:  19
# De  3.77 sec a  3.804  sec
# Amount of peaks total:  25
# De  3.78 sec a  3.814  sec
# Amount of peaks total:  25
# De  3.79 sec a  3.824  sec
# Amount of peaks total:  25
# De  3.8 sec a  3.834  sec
# Amount of peaks total:  25
# De  3.81 sec a  3.844  sec
# Amount of peaks total:  25
# De  3.82 sec a  3.854  sec
# Amount of peaks total:  25
# De  3.83 sec a  3.864  sec
# Amount of peaks total:  25
# De  3.84 sec a  3.874  sec
# Amount of peaks total:  28
# De  3.85 sec a  3.884  sec
# Amount of peaks total:  28
# De  3.86 sec a  3.894  sec
# Amount of peaks total:  25
# De  3.87 sec a  3.904  sec
# Amount of peaks total:  18
# De  3.88 sec a  3.914  sec
# Amount of peaks total:  11
# De  3.89 sec a  3.924  sec
# Amount of peaks total:  10
# De  3.9 sec a  3.934  sec
# Amount of peaks total:  8
# De  3.91 sec a  3.944  sec
# Amount of peaks total:  4
# De  3.92 sec a  3.954  sec
# Amount of peaks total:  6
# De  3.93 sec a  3.964  sec
# Amount of peaks total:  7
# De  3.94 sec a  3.974  sec
# Amount of peaks total:  7
# De  3.95 sec a  3.984  sec
# Amount of peaks total:  7
# De  3.96 sec a  3.994  sec
# Amount of peaks total:  10
# De  3.97 sec a  4.004  sec
# Amount of peaks total:  19
# De  3.98 sec a  4.014  sec
# Amount of peaks total:  15
# De  3.99 sec a  4.024  sec
# Amount of peaks total:  55
# De  4.0 sec a  4.034  sec
# Amount of peaks total:  118
# De  4.01 sec a  4.044  sec
# Amount of peaks total:  55
# De  4.02 sec a  4.054  sec
# Amount of peaks total:  65
# De  4.03 sec a  4.064  sec
# Amount of peaks total:  55
# De  4.04 sec a  4.074  sec
# Amount of peaks total:  42
# De  4.05 sec a  4.084  sec
# Amount of peaks total:  46
# De  4.06 sec a  4.094  sec
# Amount of peaks total:  44
# De  4.07 sec a  4.104  sec
# Amount of peaks total:  39
# De  4.08 sec a  4.114  sec
# Amount of peaks total:  36
# De  4.09 sec a  4.124  sec
# Amount of peaks total:  37
# De  4.1 sec a  4.134  sec
# Amount of peaks total:  70
# De  4.11 sec a  4.144  sec
# Amount of peaks total:  74
# De  4.12 sec a  4.154  sec
# Amount of peaks total:  141
# De  4.13 sec a  4.164  sec
# Amount of peaks total:  278
# De  4.14 sec a  4.174  sec
# Amount of peaks total:  250
# De  4.15 sec a  4.184  sec
# Amount of peaks total:  179
# De  4.16 sec a  4.194  sec
# Amount of peaks total:  40
# De  4.17 sec a  4.204  sec
# Amount of peaks total:  35
# De  4.18 sec a  4.214  sec
# Amount of peaks total:  35
# De  4.19 sec a  4.224  sec
# Amount of peaks total:  34
# De  4.2 sec a  4.234  sec
# Amount of peaks total:  46
# De  4.21 sec a  4.244  sec
# Amount of peaks total:  40
# De  4.22 sec a  4.254  sec
# Amount of peaks total:  46
# De  4.23 sec a  4.264  sec
# Amount of peaks total:  40
# De  4.24 sec a  4.274  sec
# Amount of peaks total:  46
# De  4.25 sec a  4.284  sec
# Amount of peaks total:  36
# De  4.26 sec a  4.294  sec
# Amount of peaks total:  43
# De  4.27 sec a  4.304  sec
# Amount of peaks total:  53
# De  4.28 sec a  4.314  sec
# Amount of peaks total:  46
# De  4.29 sec a  4.324  sec
# Amount of peaks total:  52
# De  4.3 sec a  4.334  sec
# Amount of peaks total:  45
# De  4.31 sec a  4.344  sec
# Amount of peaks total:  36
# De  4.32 sec a  4.354  sec
# Amount of peaks total:  38
# De  4.33 sec a  4.364  sec
# Amount of peaks total:  35
# De  4.34 sec a  4.374  sec
# Amount of peaks total:  34
# De  4.35 sec a  4.384  sec
# Amount of peaks total:  36
# De  4.36 sec a  4.394  sec
# Amount of peaks total:  39
# De  4.37 sec a  4.404  sec
# Amount of peaks total:  38
# De  4.38 sec a  4.414  sec
# Amount of peaks total:  32
# De  4.39 sec a  4.424  sec
# Amount of peaks total:  31
# De  4.4 sec a  4.434  sec
# Amount of peaks total:  33
# De  4.41 sec a  4.444  sec
# Amount of peaks total:  38
# De  4.42 sec a  4.454  sec
# Amount of peaks total:  33
# De  4.43 sec a  4.464  sec
# Amount of peaks total:  30
# De  4.44 sec a  4.474  sec
# Amount of peaks total:  28
# De  4.45 sec a  4.484  sec
# Amount of peaks total:  24
# De  4.46 sec a  4.494  sec
# Amount of peaks total:  28
# De  4.47 sec a  4.504  sec
# Amount of peaks total:  51
# De  4.48 sec a  4.514  sec
# Amount of peaks total:  136
# De  4.49 sec a  4.524  sec
# Amount of peaks total:  239
# De  4.5 sec a  4.534  sec
# Amount of peaks total:  259
# De  4.51 sec a  4.544  sec
# Amount of peaks total:  264
# De  4.52 sec a  4.554  sec
# Amount of peaks total:  292
# De  4.53 sec a  4.564  sec
# Amount of peaks total:  284
# De  4.54 sec a  4.574  sec
# Amount of peaks total:  280
# De  4.55 sec a  4.584  sec
# Amount of peaks total:  268
# De  4.56 sec a  4.594  sec
# Amount of peaks total:  306
# De  4.57 sec a  4.604  sec
# Amount of peaks total:  353
# De  4.58 sec a  4.614  sec
# Amount of peaks total:  36
# De  4.59 sec a  4.624  sec
# Amount of peaks total:  12
# De  4.6 sec a  4.634  sec
# Amount of peaks total:  13
# De  4.61 sec a  4.644  sec
# Amount of peaks total:  13
# De  4.62 sec a  4.654  sec
# Amount of peaks total:  10
# De  4.63 sec a  4.664  sec
# Amount of peaks total:  10
# De  4.64 sec a  4.674  sec
# Amount of peaks total:  11
# De  4.65 sec a  4.684  sec
# Amount of peaks total:  11
# De  4.66 sec a  4.694  sec
# Amount of peaks total:  12
# De  4.67 sec a  4.704  sec
# Amount of peaks total:  12
# De  4.68 sec a  4.714  sec
# Amount of peaks total:  13
# De  4.69 sec a  4.724  sec
# Amount of peaks total:  13
# De  4.7 sec a  4.734  sec
# Amount of peaks total:  13
# De  4.71 sec a  4.744  sec
# Amount of peaks total:  15
# De  4.72 sec a  4.754  sec
# Amount of peaks total:  16
# De  4.73 sec a  4.764  sec
# Amount of peaks total:  18
# De  4.74 sec a  4.774  sec
# Amount of peaks total:  18
# De  4.75 sec a  4.784  sec
# Amount of peaks total:  23
# De  4.76 sec a  4.794  sec
# Amount of peaks total:  17
# De  4.77 sec a  4.804  sec
# Amount of peaks total:  24
# De  4.78 sec a  4.814  sec
# Amount of peaks total:  22
# De  4.79 sec a  4.824  sec
# Amount of peaks total:  31
# De  4.8 sec a  4.834  sec
# Amount of peaks total:  38
# De  4.81 sec a  4.844  sec
# Amount of peaks total:  38
# De  4.82 sec a  4.854  sec
# Amount of peaks total:  38
# De  4.83 sec a  4.864  sec
# Amount of peaks total:  25
# De  4.84 sec a  4.874  sec
# Amount of peaks total:  17
# De  4.85 sec a  4.884  sec
# Amount of peaks total:  16
# De  4.86 sec a  4.894  sec
# Amount of peaks total:  15
# De  4.87 sec a  4.904  sec
# Amount of peaks total:  14
# De  4.88 sec a  4.914  sec
# Amount of peaks total:  14
# De  4.89 sec a  4.924  sec
# Amount of peaks total:  14
# De  4.9 sec a  4.934  sec
# Amount of peaks total:  14
# De  4.91 sec a  4.944  sec
# Amount of peaks total:  14
# De  4.92 sec a  4.954  sec
# Amount of peaks total:  14
# De  4.93 sec a  4.964  sec
# Amount of peaks total:  14
# De  4.94 sec a  4.974  sec
# Amount of peaks total:  13
# De  4.95 sec a  4.984  sec
# Amount of peaks total:  13
# De  4.96 sec a  4.994  sec
# Amount of peaks total:  9
# De  4.97 sec a  5.004  sec
# Amount of peaks total:  5
# De  4.98 sec a  5.014  sec
# Amount of peaks total:  6
# De  4.99 sec a  5.024  sec
# Amount of peaks total:  5
# De  5.0 sec a  5.034  sec
# Amount of peaks total:  10
# De  5.01 sec a  5.044  sec
# Amount of peaks total:  10
# De  5.02 sec a  5.054  sec
# Amount of peaks total:  10
# De  5.03 sec a  5.064  sec
# Amount of peaks total:  14
# De  5.04 sec a  5.074  sec
# Amount of peaks total:  18
# De  5.05 sec a  5.084  sec
# Amount of peaks total:  21
# De  5.06 sec a  5.094  sec
# Amount of peaks total:  21
# De  5.07 sec a  5.104  sec
# Amount of peaks total:  27
# De  5.08 sec a  5.114  sec
# Amount of peaks total:  31
# De  5.09 sec a  5.124  sec
# Amount of peaks total:  31
# De  5.1 sec a  5.134  sec
# Amount of peaks total:  30
# De  5.11 sec a  5.144  sec
# Amount of peaks total:  24
# De  5.12 sec a  5.154  sec
# Amount of peaks total:  25
# De  5.13 sec a  5.164  sec
# Amount of peaks total:  22
# De  5.14 sec a  5.174  sec
# Amount of peaks total:  22
# De  5.15 sec a  5.184  sec
# Amount of peaks total:  22
# De  5.16 sec a  5.194  sec
# Amount of peaks total:  22
# De  5.17 sec a  5.204  sec
# Amount of peaks total:  22
# De  5.18 sec a  5.214  sec
# Amount of peaks total:  26
# De  5.19 sec a  5.224  sec
# Amount of peaks total:  32
# De  5.2 sec a  5.234  sec
# Amount of peaks total:  21
# De  5.21 sec a  5.244  sec
# Amount of peaks total:  17
# De  5.22 sec a  5.254  sec
# Amount of peaks total:  17
# De  5.23 sec a  5.264  sec
# Amount of peaks total:  17
# De  5.24 sec a  5.274  sec
# Amount of peaks total:  12
# De  5.25 sec a  5.284  sec
# Amount of peaks total:  9
# De  5.26 sec a  5.294  sec
# Amount of peaks total:  13
# De  5.27 sec a  5.304  sec
# Amount of peaks total:  38
# De  5.28 sec a  5.314  sec
# Amount of peaks total:  51
# De  5.29 sec a  5.324  sec
# Amount of peaks total:  40
# De  5.3 sec a  5.334  sec
# Amount of peaks total:  17
# De  5.31 sec a  5.344  sec
# Amount of peaks total:  22
# De  5.32 sec a  5.354  sec
# Amount of peaks total:  47
# De  5.33 sec a  5.364  sec
# Amount of peaks total:  65
# De  5.34 sec a  5.374  sec
# Amount of peaks total:  61
# De  5.35 sec a  5.384  sec
# Amount of peaks total:  109
# De  5.36 sec a  5.394  sec
# Amount of peaks total:  46
# De  5.37 sec a  5.404  sec
# Amount of peaks total:  84
# De  5.38 sec a  5.414  sec
# Amount of peaks total:  66
# De  5.39 sec a  5.424  sec
# Amount of peaks total:  59
# De  5.4 sec a  5.434  sec
# Amount of peaks total:  45
# De  5.41 sec a  5.444  sec
# Amount of peaks total:  34
# De  5.42 sec a  5.454  sec
# Amount of peaks total:  17
# De  5.43 sec a  5.464  sec
# Amount of peaks total:  23
# De  5.44 sec a  5.474  sec
# Amount of peaks total:  20
# De  5.45 sec a  5.484  sec
# Amount of peaks total:  19
# De  5.46 sec a  5.494  sec
# Amount of peaks total:  19
# De  5.47 sec a  5.504  sec
# Amount of peaks total:  19
# De  5.48 sec a  5.514  sec
# Amount of peaks total:  19
# De  5.49 sec a  5.524  sec
# Amount of peaks total:  13
# De  5.5 sec a  5.534  sec
# Amount of peaks total:  25
# De  5.51 sec a  5.544  sec
# Amount of peaks total:  62
# De  5.52 sec a  5.554  sec
# Amount of peaks total:  21
# De  5.53 sec a  5.564  sec
# Amount of peaks total:  12
# De  5.54 sec a  5.574  sec
# Amount of peaks total:  9
# De  5.55 sec a  5.584  sec
# Amount of peaks total:  10
# De  5.56 sec a  5.594  sec
# Amount of peaks total:  91
# De  5.57 sec a  5.604  sec
# Amount of peaks total:  186
# De  5.58 sec a  5.614  sec
# Amount of peaks total:  201
# De  5.59 sec a  5.624  sec
# Amount of peaks total:  210
# De  5.6 sec a  5.634  sec
# Amount of peaks total:  222
# De  5.61 sec a  5.644  sec
# Amount of peaks total:  234
# De  5.62 sec a  5.654  sec
# Amount of peaks total:  220
# De  5.63 sec a  5.664  sec
# Amount of peaks total:  216
# De  5.64 sec a  5.674  sec
# Amount of peaks total:  198
# De  5.65 sec a  5.684  sec
# Amount of peaks total:  173
# De  5.66 sec a  5.694  sec
# Amount of peaks total:  143
# De  5.67 sec a  5.704  sec
# Amount of peaks total:  123
# De  5.68 sec a  5.714  sec
# Amount of peaks total:  114
# De  5.69 sec a  5.724  sec
# Amount of peaks total:  104
# De  5.7 sec a  5.734  sec
# Amount of peaks total:  22
# De  5.71 sec a  5.744  sec
# Amount of peaks total:  12
# De  5.72 sec a  5.754  sec
# Amount of peaks total:  12
# De  5.73 sec a  5.764  sec
# Amount of peaks total:  18
# De  5.74 sec a  5.774  sec
# Amount of peaks total:  24
# De  5.75 sec a  5.784  sec
# Amount of peaks total:  20
# De  5.76 sec a  5.794  sec
# Amount of peaks total:  21
# De  5.77 sec a  5.804  sec
# Amount of peaks total:  17
# De  5.78 sec a  5.814  sec
# Amount of peaks total:  14
# De  5.79 sec a  5.824  sec
# Amount of peaks total:  15
# De  5.8 sec a  5.834  sec
# Amount of peaks total:  16
# De  5.81 sec a  5.844  sec
# Amount of peaks total:  12
# De  5.82 sec a  5.854  sec
# Amount of peaks total:  119
# De  5.83 sec a  5.864  sec
# Amount of peaks total:  256
# De  5.84 sec a  5.874  sec
# Amount of peaks total:  274
# De  5.85 sec a  5.884  sec
# Amount of peaks total:  257
# De  5.86 sec a  5.894  sec
# Amount of peaks total:  237
# De  5.87 sec a  5.904  sec
# Amount of peaks total:  234
# De  5.88 sec a  5.914  sec
# Amount of peaks total:  235
# De  5.89 sec a  5.924  sec
# Amount of peaks total:  238
# De  5.9 sec a  5.934  sec
# Amount of peaks total:  181
# De  5.91 sec a  5.944  sec
# Amount of peaks total:  39
# De  5.92 sec a  5.954  sec
# Amount of peaks total:  14
# De  5.93 sec a  5.964  sec
# Amount of peaks total:  15
# De  5.94 sec a  5.974  sec
# Amount of peaks total:  15
# De  5.95 sec a  5.984  sec
# Amount of peaks total:  10
# De  5.96 sec a  5.994  sec
# Amount of peaks total:  7
# De  5.97 sec a  6.004  sec
# Amount of peaks total:  8
# De  5.98 sec a  6.014  sec
# Amount of peaks total:  7
# De  5.99 sec a  6.024  sec
# Amount of peaks total:  9
# De  6.0 sec a  6.034  sec
# Amount of peaks total:  7
# De  6.01 sec a  6.044  sec
# Amount of peaks total:  9
# De  6.02 sec a  6.054  sec
# Amount of peaks total:  10
# De  6.03 sec a  6.064  sec
# Amount of peaks total:  22
# De  6.04 sec a  6.074  sec
# Amount of peaks total:  51
# De  6.05 sec a  6.084  sec
# Amount of peaks total:  139
# De  6.06 sec a  6.094  sec
# Amount of peaks total:  119
# De  6.07 sec a  6.104  sec
# Amount of peaks total:  194
# De  6.08 sec a  6.114  sec
# Amount of peaks total:  74
# De  6.09 sec a  6.124  sec
# Amount of peaks total:  60
# De  6.1 sec a  6.134  sec
# Amount of peaks total:  47
# De  6.11 sec a  6.144  sec
# Amount of peaks total:  35
# De  6.12 sec a  6.154  sec
# Amount of peaks total:  26
# De  6.13 sec a  6.164  sec
# Amount of peaks total:  27
# De  6.14 sec a  6.174  sec
# Amount of peaks total:  25
# De  6.15 sec a  6.184  sec
# Amount of peaks total:  25
# De  6.16 sec a  6.194  sec
# Amount of peaks total:  26
# De  6.17 sec a  6.204  sec
# Amount of peaks total:  15
# De  6.18 sec a  6.214  sec
# Amount of peaks total:  6
# De  6.19 sec a  6.224  sec
# Amount of peaks total:  6
# De  6.2 sec a  6.234  sec
# Amount of peaks total:  11
# De  6.21 sec a  6.244  sec
# Amount of peaks total:  17
# De  6.22 sec a  6.254  sec
# Amount of peaks total:  17
# De  6.23 sec a  6.264  sec
# Amount of peaks total:  19
# De  6.24 sec a  6.274  sec
# Amount of peaks total:  23
# De  6.25 sec a  6.284  sec
# Amount of peaks total:  26
# De  6.26 sec a  6.294  sec
# Amount of peaks total:  21
# De  6.27 sec a  6.304  sec
# Amount of peaks total:  14
# De  6.28 sec a  6.314  sec
# Amount of peaks total:  12
# De  6.29 sec a  6.324  sec
# Amount of peaks total:  16
# De  6.3 sec a  6.334  sec
# Amount of peaks total:  12
# De  6.31 sec a  6.344  sec
# Amount of peaks total:  12
# De  6.32 sec a  6.354  sec
# Amount of peaks total:  11
# De  6.33 sec a  6.364  sec
# Amount of peaks total:  10
# De  6.34 sec a  6.374  sec
# Amount of peaks total:  11
# De  6.35 sec a  6.384  sec
# Amount of peaks total:  11
# De  6.36 sec a  6.394  sec
# Amount of peaks total:  9
# De  6.37 sec a  6.404  sec
# Amount of peaks total:  12
# De  6.38 sec a  6.414  sec
# Amount of peaks total:  16
# De  6.39 sec a  6.424  sec
# Amount of peaks total:  17
# De  6.4 sec a  6.434  sec
# Amount of peaks total:  25
# De  6.41 sec a  6.444  sec
# Amount of peaks total:  28
# De  6.42 sec a  6.454  sec
# Amount of peaks total:  28
# De  6.43 sec a  6.464  sec
# Amount of peaks total:  26
# De  6.44 sec a  6.474  sec
# Amount of peaks total:  31
# De  6.45 sec a  6.484  sec
# Amount of peaks total:  29
# De  6.46 sec a  6.494  sec
# Amount of peaks total:  36
# De  6.47 sec a  6.504  sec
# Amount of peaks total:  27
# De  6.48 sec a  6.514  sec
# Amount of peaks total:  21
# De  6.49 sec a  6.524  sec
# Amount of peaks total:  8
# De  6.5 sec a  6.534  sec
# Amount of peaks total:  8
# De  6.51 sec a  6.544  sec
# Amount of peaks total:  8
# De  6.52 sec a  6.554  sec
# Amount of peaks total:  9
# De  6.53 sec a  6.564  sec
# Amount of peaks total:  8
# De  6.54 sec a  6.574  sec
# Amount of peaks total:  12
# De  6.55 sec a  6.584  sec
# Amount of peaks total:  9
# De  6.56 sec a  6.594  sec
# Amount of peaks total:  61
# De  6.57 sec a  6.604  sec
# Amount of peaks total:  157
# De  6.58 sec a  6.614  sec
# Amount of peaks total:  112
# De  6.59 sec a  6.624  sec
# Amount of peaks total:  86
# De  6.6 sec a  6.634  sec
# Amount of peaks total:  78
# De  6.61 sec a  6.644  sec
# Amount of peaks total:  84
# De  6.62 sec a  6.654  sec
# Amount of peaks total:  80
# De  6.63 sec a  6.664  sec
# Amount of peaks total:  73
# De  6.64 sec a  6.674  sec
# Amount of peaks total:  79
# De  6.65 sec a  6.684  sec
# Amount of peaks total:  82
# De  6.66 sec a  6.694  sec
# Amount of peaks total:  78
# De  6.67 sec a  6.704  sec
# Amount of peaks total:  72
# De  6.68 sec a  6.714  sec
# Amount of peaks total:  72
# De  6.69 sec a  6.724  sec
# Amount of peaks total:  70
# De  6.7 sec a  6.734  sec
# Amount of peaks total:  18
# De  6.71 sec a  6.744  sec
# Amount of peaks total:  18
# De  6.72 sec a  6.754  sec
# Amount of peaks total:  18
# De  6.73 sec a  6.764  sec
# Amount of peaks total:  19
# De  6.74 sec a  6.774  sec
# Amount of peaks total:  20
# De  6.75 sec a  6.784  sec
# Amount of peaks total:  24
# De  6.76 sec a  6.794  sec
# Amount of peaks total:  29
# De  6.77 sec a  6.804  sec
# Amount of peaks total:  30
# De  6.78 sec a  6.814  sec
# Amount of peaks total:  29
# De  6.79 sec a  6.824  sec
# Amount of peaks total:  27
# De  6.8 sec a  6.834  sec
# Amount of peaks total:  26
# De  6.81 sec a  6.844  sec
# Amount of peaks total:  41
# De  6.82 sec a  6.854  sec
# Amount of peaks total:  29
# De  6.83 sec a  6.864  sec
# Amount of peaks total:  59
# De  6.84 sec a  6.874  sec
# Amount of peaks total:  50
# De  6.85 sec a  6.884  sec
# Amount of peaks total:  47
# De  6.86 sec a  6.894  sec
# Amount of peaks total:  97
# De  6.87 sec a  6.904  sec
# Amount of peaks total:  136
# De  6.88 sec a  6.914  sec
# Amount of peaks total:  180
# De  6.89 sec a  6.924  sec
# Amount of peaks total:  243
# De  6.9 sec a  6.934  sec
# Amount of peaks total:  320
# De  6.91 sec a  6.944  sec
# Amount of peaks total:  148
# De  6.92 sec a  6.954  sec
# Amount of peaks total:  83
# De  6.93 sec a  6.964  sec
# Amount of peaks total:  47
# De  6.94 sec a  6.974  sec
# Amount of peaks total:  44
# De  6.95 sec a  6.984  sec
# Amount of peaks total:  41
# De  6.96 sec a  6.994  sec
# Amount of peaks total:  39
# De  6.97 sec a  7.004  sec
# Amount of peaks total:  35
# De  6.98 sec a  7.014  sec
# Amount of peaks total:  35
# De  6.99 sec a  7.024  sec
# Amount of peaks total:  48
# De  7.0 sec a  7.034  sec
# Amount of peaks total:  47
# De  7.01 sec a  7.044  sec
# Amount of peaks total:  65
# De  7.02 sec a  7.054  sec
# Amount of peaks total:  127
# De  7.03 sec a  7.064  sec
# Amount of peaks total:  196
# De  7.04 sec a  7.074  sec
# Amount of peaks total:  175
# De  7.05 sec a  7.084  sec
# Amount of peaks total:  279
# De  7.06 sec a  7.094  sec
# Amount of peaks total:  295
# De  7.07 sec a  7.104  sec
# Amount of peaks total:  309
# De  7.08 sec a  7.114  sec
# Amount of peaks total:  290
# De  7.09 sec a  7.124  sec
# Amount of peaks total:  219
# De  7.1 sec a  7.134  sec
# Amount of peaks total:  213
# De  7.11 sec a  7.144  sec
# Amount of peaks total:  213
# De  7.12 sec a  7.154  sec
# Amount of peaks total:  191
# De  7.13 sec a  7.164  sec
# Amount of peaks total:  179
# De  7.14 sec a  7.174  sec
# Amount of peaks total:  156
# De  7.15 sec a  7.184  sec
# Amount of peaks total:  164
# De  7.16 sec a  7.194  sec
# Amount of peaks total:  153
# De  7.17 sec a  7.204  sec
# Amount of peaks total:  151
# De  7.18 sec a  7.214  sec
# Amount of peaks total:  139
# De  7.19 sec a  7.224  sec
# Amount of peaks total:  141
# De  7.2 sec a  7.234  sec
# Amount of peaks total:  145
# De  7.21 sec a  7.244  sec
# Amount of peaks total:  152
# De  7.22 sec a  7.254  sec
# Amount of peaks total:  143
# De  7.23 sec a  7.264  sec
# Amount of peaks total:  150
# De  7.24 sec a  7.274  sec
# Amount of peaks total:  150
# De  7.25 sec a  7.284  sec
# Amount of peaks total:  139
# De  7.26 sec a  7.294  sec
# Amount of peaks total:  167
# De  7.27 sec a  7.304  sec
# Amount of peaks total:  150
# De  7.28 sec a  7.314  sec
# Amount of peaks total:  141
# De  7.29 sec a  7.324  sec
# Amount of peaks total:  152
# De  7.3 sec a  7.334  sec
# Amount of peaks total:  166
# De  7.31 sec a  7.344  sec
# Amount of peaks total:  160
# De  7.32 sec a  7.354  sec
# Amount of peaks total:  162
# De  7.33 sec a  7.364  sec
# Amount of peaks total:  150
# De  7.34 sec a  7.374  sec
# Amount of peaks total:  158
# De  7.35 sec a  7.384  sec
# Amount of peaks total:  160
# De  7.36 sec a  7.394  sec
# Amount of peaks total:  159
# De  7.37 sec a  7.404  sec
# Amount of peaks total:  181
# De  7.38 sec a  7.414  sec
# Amount of peaks total:  168
# De  7.39 sec a  7.424  sec
# Amount of peaks total:  195
# De  7.4 sec a  7.434  sec
# Amount of peaks total:  187
# De  7.41 sec a  7.444  sec
# Amount of peaks total:  176
# De  7.42 sec a  7.454  sec
# Amount of peaks total:  191
# De  7.43 sec a  7.464  sec
# Amount of peaks total:  175
# De  7.44 sec a  7.474  sec
# Amount of peaks total:  177
# De  7.45 sec a  7.484  sec
# Amount of peaks total:  169
# De  7.46 sec a  7.494  sec
# Amount of peaks total:  177
# De  7.47 sec a  7.504  sec
# Amount of peaks total:  178
# De  7.48 sec a  7.514  sec
# Amount of peaks total:  179
# De  7.49 sec a  7.524  sec
# Amount of peaks total:  148
# De  7.5 sec a  7.534  sec
# Amount of peaks total:  166
# De  7.51 sec a  7.544  sec
# Amount of peaks total:  146
# De  7.52 sec a  7.554  sec
# Amount of peaks total:  148
# De  7.53 sec a  7.564  sec
# Amount of peaks total:  177
# De  7.54 sec a  7.574  sec
# Amount of peaks total:  185
# De  7.55 sec a  7.584  sec
# Amount of peaks total:  171
# De  7.56 sec a  7.594  sec
# Amount of peaks total:  158
# De  7.57 sec a  7.604  sec
# Amount of peaks total:  157
# De  7.58 sec a  7.614  sec
# Amount of peaks total:  182
# De  7.59 sec a  7.624  sec
# Amount of peaks total:  179
# De  7.6 sec a  7.634  sec
# Amount of peaks total:  163
# De  7.61 sec a  7.644  sec
# Amount of peaks total:  184
# De  7.62 sec a  7.654  sec
# Amount of peaks total:  180
# De  7.63 sec a  7.664  sec
# Amount of peaks total:  181
# De  7.64 sec a  7.674  sec
# Amount of peaks total:  177
# De  7.65 sec a  7.684  sec
# Amount of peaks total:  163
# De  7.66 sec a  7.694  sec
# Amount of peaks total:  171
# De  7.67 sec a  7.704  sec
# Amount of peaks total:  175
# De  7.68 sec a  7.714  sec
# Amount of peaks total:  155
# De  7.69 sec a  7.724  sec
# Amount of peaks total:  166
# De  7.7 sec a  7.734  sec
# Amount of peaks total:  159
# De  7.71 sec a  7.744  sec
# Amount of peaks total:  157
# De  7.72 sec a  7.754  sec
# Amount of peaks total:  149
# De  7.73 sec a  7.764  sec
# Amount of peaks total:  163
# De  7.74 sec a  7.774  sec
# Amount of peaks total:  158
# De  7.75 sec a  7.784  sec
# Amount of peaks total:  185
# De  7.76 sec a  7.794  sec
# Amount of peaks total:  174
# De  7.77 sec a  7.804  sec
# Amount of peaks total:  159
# De  7.78 sec a  7.814  sec
# Amount of peaks total:  185
# De  7.79 sec a  7.824  sec
# De  7.8 sec a  7.834  sec
# De  7.81 sec a  7.844  sec
# De  7.82 sec a  7.854  sec
# De  7.83 sec a  7.864  sec
# De  7.84 sec a  7.874  sec
# De  7.85 sec a  7.884  sec
# De  7.86 sec a  7.894  sec
# De  7.87 sec a  7.904  sec
# De  7.88 sec a  7.914  sec
# De  7.89 sec a  7.924  sec
# De  7.9 sec a  7.934  sec
# De  7.91 sec a  7.944  sec
# De  7.92 sec a  7.954  sec
# De  7.93 sec a  7.964  sec
# De  7.94 sec a  7.974  sec
# De  7.95 sec a  7.984  sec
# De  7.96 sec a  7.994  sec
# De  7.97 sec a  8.004  sec
# De  7.98 sec a  8.014  sec
# De  7.99 sec a  8.024  sec
# De  8.0 sec a  8.034  sec
# De  8.01 sec a  8.044  sec
# De  8.02 sec a  8.054  sec
# De  8.03 sec a  8.064  sec
# De  8.04 sec a  8.074  sec
# De  8.05 sec a  8.084  sec
# De  8.06 sec a  8.094  sec
# De  8.07 sec a  8.104  sec
# De  8.08 sec a  8.114  sec
# De  8.09 sec a  8.124  sec
# De  8.1 sec a  8.134  sec
# De  8.11 sec a  8.144  sec
# De  8.12 sec a  8.154  sec
# De  8.13 sec a  8.164  sec
# De  8.14 sec a  8.174  sec
# De  8.15 sec a  8.184  sec
# De  8.16 sec a  8.194  sec
# De  8.17 sec a  8.204  sec
# De  8.18 sec a  8.214  sec
# De  8.19 sec a  8.224  sec
# De  8.2 sec a  8.234  sec
# De  8.21 sec a  8.244  sec
# De  8.22 sec a  8.254  sec
# De  8.23 sec a  8.264  sec
# De  8.24 sec a  8.274  sec
# De  8.25 sec a  8.284  sec
# De  8.26 sec a  8.294  sec
# De  8.27 sec a  8.304  sec
# De  8.28 sec a  8.314  sec
# De  8.29 sec a  8.324  sec
# De  8.3 sec a  8.334  sec
# De  8.31 sec a  8.344  sec
# De  8.32 sec a  8.354  sec
# De  8.33 sec a  8.364  sec
# De  8.34 sec a  8.374  sec
# De  8.35 sec a  8.384  sec
# De  8.36 sec a  8.394  sec
# De  8.37 sec a  8.404  sec
# Gross error: 8.742514970059881 %

# %% [markdown]
# # Trying the algorithms on the dataset
#
# We test the algorithms on a fraction of the dataset (approximately 1%).

# %%
def get_files(path, to_store1, to_store2, index1=None, index2=None):
  aux_files = [f for f in listdir(path) if isfile(join(path, f))]

  if index1 is None:
    first1 = randint(0, len(aux_files)-1)

    to_store1.append(path + '/' + aux_files[first1])
    to_store2.append(path.replace('MIC', 'REF') + '/' +'ref' + aux_files[first1][3:len(aux_files[first1])-3] + 'f0')
    aux_files.pop(first1)
    
    first2 = randint(0, len(aux_files)-1)

    to_store1.append(path + '/' + aux_files[first2])
    to_store2.append(path.replace('MIC', 'REF') +'/' +'ref' + aux_files[first2][3:len(aux_files[first2])-3] + 'f0')
    aux_files.pop(first2)

    first3 = randint(0, len(aux_files)-1)

    to_store1.append(path + '/' + aux_files[first3])
    to_store2.append(path.replace('MIC', 'REF') + '/' +'ref' + aux_files[first3][3:len(aux_files[first3])-3] + 'f0')
    aux_files.pop(first3)

    first4 = randint(0, len(aux_files)-1)

    to_store1.append(path + '/' + aux_files[first4])
    to_store2.append(path.replace('MIC', 'REF') + '/' +'ref' + aux_files[first4][3:len(aux_files[first4])-3] + 'f0')
    aux_files.pop(first4)

    first5 = randint(0, len(aux_files)-1)

    to_store1.append(path + '/' + aux_files[first5])
    to_store2.append(path.replace('MIC', 'REF') + '/' +'ref' + aux_files[first5][3:len(aux_files[first5])-3] + 'f0')
    aux_files.pop(first5)

    first6 = randint(0, len(aux_files)-1)

    to_store1.append(path + '/' + aux_files[first6])
    to_store2.append(path.replace('MIC', 'REF') + '/' +'ref' + aux_files[first6][3:len(aux_files[first6])-3] + 'f0')

# %%
from os import listdir
from os.path import isfile, join
from random import randint

female_paths_mic = [ '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F0' + str(i) for i in range(1, 10)] 
female_paths_mic.append('/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F10')
female_paths_ref = ['/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F0' + str(i) for i in range(1, 10)]
female_paths_ref.append('/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F10')

male_paths_mic = ['/content/drive/Shared drives/Pitch Tracking/MALE/MIC/M0' + str(i) for i in range(1, 10)] 
male_paths_mic.append('/content/drive/Shared drives/Pitch Tracking/MALE/MIC/M10')
male_paths_ref = ['/content/drive/Shared drives/Pitch Tracking/MALE/REF/M0' + str(i) for i in range(1, 10)] 
male_paths_ref.append('/content/drive/Shared drives/Pitch Tracking/MALE/REF/M10')

female_files_mic = []
female_files_ref = []

for i in range(len(female_paths_mic)):
  get_files(female_paths_mic[i], female_files_mic, female_files_ref)


male_files_mic = []
male_files_ref = []
for i in range(len(male_paths_mic)):
  get_files(male_paths_mic[i], male_files_mic, male_files_ref)
  
print(female_files_mic)
print(female_files_ref)
# Out:
# ['/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si550.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si565.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si637.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si574.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si521.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F01/mic_F01_si624.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si661.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si705.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si727.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si779.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si701.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_sx87.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si944.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_sx120.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si915.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si898.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si910.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si1000.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F04/mic_F04_si1064.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F04/mic_F04_si1050.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F04/mic_F04_si1195.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F04/mic_F04_si1105.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F04/mic_F04_si1180.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F04/mic_F04_si1044.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F05/mic_F05_si1231.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F05/mic_F05_sx202.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F05/mic_F05_si1263.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F05/mic_F05_si1242.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F05/mic_F05_si1314.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F05/mic_F05_sa1.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F06/mic_F06_si1426.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F06/mic_F06_si1553.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F06/mic_F06_si1408.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F06/mic_F06_si1471.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F06/mic_F06_si1513.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F06/mic_F06_sx260.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F07/mic_F07_si1637.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F07/mic_F07_si1700.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F07/mic_F07_si1712.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F07/mic_F07_si1643.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F07/mic_F07_si1754.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F07/mic_F07_si1618.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F08/mic_F08_si1786.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F08/mic_F08_si1850.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F08/mic_F08_sx361.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F08/mic_F08_si1916.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F08/mic_F08_si1805.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F08/mic_F08_si1810.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F09/mic_F09_si1985.wav', '/content/drive/Shared drives/Pitch Tracking/FEMALE/MI ...
# ['/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si550.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si565.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si637.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si574.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si521.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F01/ref_F01_si624.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F02/ref_F02_si661.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F02/ref_F02_si705.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F02/ref_F02_si727.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F02/ref_F02_si779.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F02/ref_F02_si701.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F02/ref_F02_sx87.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F03/ref_F03_si944.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F03/ref_F03_sx120.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F03/ref_F03_si915.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F03/ref_F03_si898.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F03/ref_F03_si910.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F03/ref_F03_si1000.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F04/ref_F04_si1064.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F04/ref_F04_si1050.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F04/ref_F04_si1195.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F04/ref_F04_si1105.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F04/ref_F04_si1180.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F04/ref_F04_si1044.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F05/ref_F05_si1231.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F05/ref_F05_sx202.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F05/ref_F05_si1263.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F05/ref_F05_si1242.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F05/ref_F05_si1314.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F05/ref_F05_sa1.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F06/ref_F06_si1426.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F06/ref_F06_si1553.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F06/ref_F06_si1408.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F06/ref_F06_si1471.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F06/ref_F06_si1513.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F06/ref_F06_sx260.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F07/ref_F07_si1637.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F07/ref_F07_si1700.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F07/ref_F07_si1712.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F07/ref_F07_si1643.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F07/ref_F07_si1754.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F07/ref_F07_si1618.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F08/ref_F08_si1786.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F08/ref_F08_si1850.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F08/ref_F08_sx361.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F08/ref_F08_si1916.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F08/ref_F08_si1805.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F08/ref_F08_si1810.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F09/ref_F09_si1985.f0', '/content/drive/Shared drives/Pitch Tracking/FEMALE/REF/F09/ref_F09_si2112.f0', '/content/drive/Shared  ...

# %%
female_errors = []
for i in range(len(female_files_mic)):
  error = create_midi(female_files_mic[i], female_files_ref[i],gender="FEMALE", algorithm='YIN')
  female_errors.append(error)

# female_errors2 = []
# for i in range(len(female_files_mic)):
#   error = create_midi(female_files_mic[i], female_files_ref[i],gender="FEMALE", algorithm='ACF')
#   female_errors2.append(error)

# female_errors3 = []
# for i in range(len(female_files_mic)):
#   error = create_midi(female_files_mic[i], female_files_ref[i],gender="FEMALE", algorithm='HPS')
#   female_errors3.append(error)

male_errors = []
for i in range(len(male_files_mic)):
  error = create_midi(male_files_mic[i], male_files_ref[i],gender="MALE", algorithm='YIN', plot=False)
  male_errors.append(error)

# male_errors2 = []
# for i in range(len(male_files_mic)):
#   error = create_midi(male_files_mic[i], male_files_ref[i],gender="MALE", algorithm='YIN', plot=False)
#   male_errors2.append(error)

# male_errors3 = []
# for i in range(len(male_files_mic)):
#   error = create_midi(male_files_mic[i], male_files_ref[i],gender="MALE", algorithm='YIN', plot=False)
#   male_errors3.append(error)

female_errors = np.array(female_errors)
# female_errors2 = np.array(female_errors2)
# female_errors3 = np.array(female_errors3)

male_errors = np.array(male_errors)
# male_errors2 = np.array(male_errors2)
# male_errors3 = np.array(male_errors3)
# Out:
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# ...
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /usr/local/lib/python3.6/dist-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)

# %%
print('Females Mean Error (%): ', female_errors.mean())
print('Females STD (%): ', female_errors.std())
plt.figure(figsize=(10,10))
plt.plot(female_errors,'o',label="YIN")
plt.xlabel("Audio Signal nº")
plt.ylabel("Gross error rate")
plt.grid(True)
#'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav'
#'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si844.wav'
print('Samples:', len(female_errors))

# print('Females Mean Error (%): ', female_errors2.mean())
# print('Females STD (%): ', female_errors2.std())
# plt.plot(female_errors2,'o',label="ACF")
# plt.xlabel("Audio Signal nº")
# plt.ylabel("Gross error rate")
# plt.grid(True)
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav'
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si844.wav'
# print('Samples:', len(female_errors2))

# print('Females Mean Error (%): ', female_errors3.mean())
# print('Females STD (%): ', female_errors3.std())
# plt.plot(female_errors3,'o',label="HPS")
# plt.xlabel("Audio Signal nº")
# plt.ylabel("Gross error rate")
# plt.legend()
# plt.grid(True)
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav'
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si844.wav'
# print('Samples:', len(female_errors3))
# Out:
# Females Mean Error (%):  6.628457250910994
# Females STD (%):  2.4941285523591716
# Samples: 60

# %%
print('Males Mean Error (%): ', male_errors.mean())
print('Males STD (%): ', male_errors.std())
plt.figure(figsize=(10,10))
plt.plot(male_errors,'o',label="YIN")
plt.xlabel("Audio Signal nº")
plt.ylabel("Gross error rate")
plt.grid(True)
#'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav'
#'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si844.wav'
print('Samples:', len(male_errors))

# print('Males Mean Error (%): ', male_errors2.mean())
# print('Males STD (%): ', male_errors2.std())
# plt.plot(male_errors2,'o',label="ACF")
# plt.xlabel("Audio Signal nº")
# plt.ylabel("Gross error rate")
# plt.grid(True)
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav'
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si844.wav'
# print('Samples:', len(male_errors2))

# print('Males Mean Error (%): ', male_errors3.mean())
# print('Males STD (%): ', male_errors3.std())
# plt.plot(male_errors3,'o',label="HPS")
# plt.xlabel("Audio Signal nº")
# plt.ylabel("Gross error rate")
# plt.legend()
# plt.grid(True)
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F02/mic_F02_si734.wav'
# #'/content/drive/Shared drives/Pitch Tracking/FEMALE/MIC/F03/mic_F03_si844.wav'
# print('Samples:', len(male_errors3))
# Out:
# Males Mean Error (%):  8.112148757758778
# Males STD (%):  4.090972616334724
# Samples: 60
